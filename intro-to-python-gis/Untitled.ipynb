# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.expand_frame_repr', False)

# Filepaths
grid_fp = r"Data/TravelTimes_to_5975375_RailwayStation.shp"
roads_fp = r"Data/roads.shp"
metro_fp = r"Data/metro.shp"

# Read files
grid = gpd.read_file(grid_fp)
roads = gpd.read_file(roads_fp)
metro = gpd.read_file(metro_fp)

# Get the CRS of the grid
gridCRS = grid.crs

# Reproject geometries using the crs of travel time grid
roads['geometry'] = roads['geometry'].to_crs(crs=gridCRS)
metro['geometry'] = metro['geometry'].to_crs(crs=gridCRS)

# Visualize the travel times into 9 classes using "Quantiles" classification scheme
# Add also a little bit of transparency with `alpha` parameter
# (ranges from 0 to 1 where 0 is fully transparent and 1 has no transparency)
my_map = grid.plot(column="car_r_t", linewidth=0.03, cmap="Reds", scheme="quantiles", k=9, alpha=0.9)

# Add roads on top of the grid
# (use ax parameter to define the map on top of which the second items are plotted)
roads.plot(ax=my_map, color="grey", linewidth=1.5)

# Add metro on top of the previous map
metro.plot(ax=my_map, color="red", linewidth=2.5)

# Remove the empty white-space around the axes
plt.tight_layout()

# Save the figure as png file with resolution of 300 dpi
outfp = r"Output/static_map.png"
plt.savefig(outfp, dpi=300)

# %%
roads
# Out:
#               NIMI              NIMI0  NRO  MTRYHM                                           geometry
# 0    Moottoriväylä      Porvoon väylä    1      80  LINESTRING (393902.4363970492 6681130.13311762...
# 1    Moottoriväylä           Kehä III    1      80  LINESTRING (398159.608959613 6679454.908297231...
# 2    Moottoriväylä           Kehä III    1      80  LINESTRING (396439.8357809301 6681548.78722944...
# 3    Moottoriväylä           Kehä III    1      80  LINESTRING (395179.6706548687 6682842.47338640...
# 4    Moottoriväylä           Kehä III    1      80  LINESTRING (394423.6116062522 6683498.13173338...
# 5    Moottoriväylä           Kehä III    1      80  LINESTRING (391921.2611702787 6684321.38411625...
# 6    Moottoriväylä           Kehä III    1      80  LINESTRING (391576.3176501537 6684406.82608608...
# 7    Moottoriväylä           Kehä III    1      80  LINESTRING (390346.8788273776 6684854.7893704,...
# 8    Moottoriväylä           Kehä III    1      80  LINESTRING (388961.7779090909 6685051.45986294...
# 9    Moottoriväylä           Kehä III    1      80  LINESTRING (388221.1400957089 6685354.82934531...
# 10   Moottoriväylä           Kehä III    1      80  LINESTRING (386418.657518515 6686133.861802643...
# 11   Moottoriväylä           Kehä III    1      80  LINESTRING (382948.595613564 6686447.41053412,...
# 12   Moottoriväylä           Kehä III    1      80  LINESTRING (381735.278474925 6685917.882183491...
# 13   Moottoriväylä           Kehä III    1      80  LINESTRING (379428.0947324475 6684380.38282301...
# 14   Moottoriväylä           Kehä III    1      80  LINESTRING (379144.6758756311 6684171.13410409...
# 15   Moottoriväylä           Kehä III    1      80  LINESTRING (376692.696322728 6683465.621302369...
# 16   Moottoriväylä           Kehä III    1      80  LINESTRING (376766.7996474223 6683532.0279644,...
# 17   Moottoriväylä           Kehä III    1      80  LINESTRING (373680.9137214884 6681667.81169767...
# 18   Moottoriväylä           Kehä III    1      80  LINESTRING (371034.019825149 6678596.004173632...
# 19   Moottoriväylä           Kehä III    1      80  LINESTRING (369752.616605063 6678181.688965974...
# 20   Moottoriväylä           Kehä III    1      80  LINESTRING (366949.1891981607 6676208.96752457...
# 21   Moottoriväylä           Kehä III    1      80  LINESTRING (365897.46287646 6674975.608965908,...
# 22   Moottoriväylä         Turunväylä    1      80  LINESTRING (372300.2898585286 6676656.39824889...
# 23   Moottoriväylä         Turunväylä    1      80  LINESTRING (375279.5434130455 6676318.61661965...
# 24   Moottoriväylä         Turunväylä    1      80  LINESTRING (379134.2996389381 6676669.00716118...
# 25   Moottoriväylä           Itäväylä    1      80  LINESTRING (388000.4943489335 6673958.67750950...
# 26   Moottoriväylä           Itäväylä    1      80  LINESTRING (390214.6527901684 6674189.91827420...
# 27   Moottoriväylä           Itäväylä    1      80  LINESTRING (391889.9567386453 6675901.63308474...
# 28   Moottoriväylä           Itäväylä    1      80  LINESTRING (392279.896589702 6676101.110718797...
# 29   Moottoriväylä           Itäväylä    1      80  LINESTRING (392367.1293647812 6676106.02203362...
# ..             ...                ...  ...     ...                                                ...
# 151  Moottoriväylä           Kehä III    1      80  LINESTRING (396713.2284305761 6681107.56215702...
# 152  Moottoriväylä         Turunväylä    1      80  LINESTRING (369752.616605063 6678181.688965974...
# 153  Moottoriväylä  Hämeenlinnanväylä    1      80  LINESTRING (381735.278474925 6685917.882183491...
# 154  Moottoriväylä        Lahdenväylä    1      80  LINESTRING (394293.6342190586 6683223.09005408...
# 155  Moottoriväylä   Muurimestarintie    1      80  LINESTRING (383859.89174707 6679445.670342543,...
# 156  Moottoriväylä      Tuusulanväylä    1      80  LINESTRING (388522.7578889425 6685160.59330052...
# 157  Moottoriväylä      Tuusulanväylä    1      80  LINESTRING (386584.2852982458 6680363.97784327...
# 158  Moottoriväylä        Mestarintie    1      80  (LINESTRING (379627.8348493814 6678485.4974932...
# 159  Moottoriväylä   Muurimestarintie    1      80  LINESTRING (380940.8115977079 6679005.36871023...
# 160  Moottoriväylä   Muurimestarintie    1      80  LINESTRING (387929.274786115 6680223.608591607...
# 161  Moottoriväylä            Kehä II    1      80  LINESTRING (375534.7674301721 6672463.99075912...
# 162  Moottoriväylä         Länsiväylä    1      80  LINESTRING (375471.7305979048 6671956.82345857...
# 163  Moottoriväylä     Leppävaarantie    1      80  LINESTRING (379193.5413356067 6677628.02778387...
# 164  Moottoriväylä           Kehä III    1      80  LINESTRING (378729.6165385343 6683911.90065641...
# 165  Moottoriväylä           Kehä III    1      80  LINESTRING (384322.4621308018 6686443.74418711...
# 166  Moottoriväylä            Kehä II    1      80  LINESTRING (375435.9753019859 6673736.74252232...
# 167  Moottoriväylä   Seppämestarintie    1      80  LINESTRING (388382.3021448052 6680014.92418400...
# 168  Moottoriväylä         Turunväylä    1      80  LINESTRING (371367.8988339914 6677215.37755355...
# 169  Moottoriväylä         Turunväylä    1      80  LINESTRING (370485.2961178022 6677746.57089649...
# 170  Moottoriväylä      Porvoon väylä    1      80  LINESTRING (397487.9614567385 6681903.73288247...
# 171  Moottoriväylä      Porvoon väylä    1      80  LINESTRING (399820.1186227896 6682208.84993709...
# 172  Moottoriväylä      Porvoon väylä    1      80  LINESTRING (401107.0430902675 6682408.99418318...
# 173  Moottoriväylä      Porvoon väylä    1      80  LINESTRING (400840.0728958648 6682298.89325822...
# 174  Moottoriväylä      Porvoon väylä    1      80  LINESTRING (398419.0269497633 6682036.94826384...
# 175  Moottoriväylä      Porvoon väylä    1      80  LINESTRING (398685.0116992355 6681975.29198860...
# 176  Moottoriväylä      Porvoon väylä    1      80  LINESTRING (401107.0430902675 6682408.99418318...
# 177  Moottoriväylä                       1      80  LINESTRING (398159.608959613 6679454.908297231...
# 178  Moottoriväylä         Turunväylä    1      80  LINESTRING (362072.6534185751 6682513.66989077...
# 179  Moottoriväylä         Länsiväylä    1      80  LINESTRING (384332.7811944739 6671521.21746284...
# 180  Moottoriväylä           Kehä III    1      80  LINESTRING (397542.4382224383 6680123.37735897...
#
# [181 rows x 5 columns]

# %%
metro
# Out:
#     NUMERO  SUUNTA                                           geometry
# 0    1300M       1  LINESTRING (395534.7026002127 6679490.08463068...
# 1    1300M       2  LINESTRING (384398.5021810767 6671336.40736277...
# 2   1300M1       1  LINESTRING (395534.7026002127 6679490.08463068...
# 3   1300M1       2  LINESTRING (393658.5074443788 6676323.19948624...
# 4   1300M2       1  LINESTRING (393658.5074443788 6676323.19948624...
# 5   1300M2       2  LINESTRING (384398.5021810767 6671336.40736277...
# 6   1300M3       1  LINESTRING (395534.7026002127 6679490.08463068...
# 7   1300M3       2  LINESTRING (384398.5021810767 6671336.40736277...
# 8    1300V       1  LINESTRING (397241.3581585942 6675915.10935408...
# 9    1300V       2  LINESTRING (384398.5021810767 6671336.40736277...
# 10  1300V1       1  LINESTRING (397241.3581585942 6675915.10935408...
# 11  1300V1       2  LINESTRING (385939.1013612214 6672140.00479559...
# 12  1300V2       1  LINESTRING (397241.3581585942 6675915.10935408...
# 13  1300V2       2  LINESTRING (393658.5074443788 6676323.19948624...
# 14  1300V3       1  LINESTRING (397241.3581585942 6675915.10935408...
# 15  1300V3       2  LINESTRING (384398.5021810767 6671336.40736277...

# %%
grid.head()
# Out:
#    car_m_d  car_m_t  car_r_d  car_r_t  from_id  pt_m_d  pt_m_t  pt_m_tt  pt_r_d  pt_r_t  pt_r_tt    to_id  walk_d  walk_t                                           geometry
# 0    32297       43    32260       48  5785640   32616     116      147   32616     108      139  5975375   32164     459  POLYGON ((382000.0001358641 6697750.000038058,...
# 1    32508       43    32471       49  5785641   32822     119      145   32822     111      133  5975375   29547     422  POLYGON ((382250.0001358146 6697750.000038053,...
# 2    30133       50    31872       56  5785642   32940     121      146   32940     113      133  5975375   29626     423  POLYGON ((382500.0001357661 6697750.000038046,...
# 3    32690       54    34429       60  5785643   33233     125      150   33233     117      144  5975375   29919     427  POLYGON ((382750.0001357181 6697750.000038039,...
# 4    31872       42    31834       48  5787544   32127     109      126   32127     101      121  5975375   31674     452  POLYGON ((381250.0001360176 6697500.000038121,...

# %%
grid["to_id"].value_counts()
# Out:
#  5975375    13140
# -1             91
# Name: to_id, dtype: int64

# %%
pop.head()
# Out:
#              pop15                                           geometry
# index_right
# 0                8  POLYGON ((25472499.99532626 6689749.005069186,...
# 1                6  POLYGON ((25472499.99532626 6685998.998064221,...
# 2                8  POLYGON ((25472499.99532626 6684249.004130405,...
# 3                7  POLYGON ((25472499.99532626 6683999.004997004,...
# 4               19  POLYGON ((25472499.99532626 6682998.998461429,...

# %%
fp = "Data\\Vaestotietoruudukko_2015.shp"
pop = gpd.read_file(fp)
pop = pop.rename(columns={'ASUKKAITA': 'pop15'})
pop = pop[["pop15", "geometry"]]
pop["geometry"] = pop["geometry"].to_crs(epsg=3879)
join = gpd.sjoin(pop, dissolved_grid, how="left", op="within")
join.groupby("dominant_service").sum()["pop15"]
# Out:
# Warning: CRS does not match!
# C:\anaconda3\lib\site-packages\numpy\lib\function_base.py:2831: RuntimeWarning: invalid value encountered in ? (vectorized)
#   outputs = ufunc(*inputs)
# dominant_service
# 5878070.0     21919
# 5878087.0    182365
# 5902043.0    179194
# 5944003.0    156188
# 5975373.0    210850
# 5978593.0    148878
# 5980260.0     54334
# Name: pop15, dtype: int64

# %%
jumbo.head()
# Out:
#    pt_r_tt_5878070  car_r_t_5878070  from_id_5878070  to_id_5878070
# 0              131               39          5785640        5878070
# 1              129               39          5785641        5878070
# 2              129               45          5785642        5878070
# 3              138               46          5785643        5878070
# 4              115               38          5787544        5878070

# %%
pop.head()
# Out:
#             pop15                                           geometry
# index_left
# 0               8  POLYGON ((25472499.99532626 6689749.005069185,...
# 1               6  POLYGON ((25472499.99532626 6685998.998064222,...
# 2               8  POLYGON ((25472499.99532626 6684249.004130407,...
# 3               7  POLYGON ((25472499.99532626 6683999.004997005,...
# 4              19  POLYGON ((25472499.99532626 6682998.998461431,...

# %%
grid_join.head()
# Out:
#                                                      geometry  min_time_pt  dominant_service
# index_left
# 0           POLYGON ((382000.0001388059 6697750.000128186,...        121.0         5902043.0
# 1           POLYGON ((382250.00013875 6697750.000128181, 3...        115.0         5902043.0
# 2           POLYGON ((382500.0001386951 6697750.000128172,...        115.0         5902043.0
# 3           POLYGON ((382750.0001386406 6697750.000128165,...        126.0         5902043.0
# 4           POLYGON ((381250.000138978 6697500.000128254, ...        103.0         5902043.0
